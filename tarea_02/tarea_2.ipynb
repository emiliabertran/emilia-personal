# %%
# lista desde -30 al 50
lista_numeros = range(-30,50)
print(lista_numeros)

for x in range(-30,51):
  if(x < 0):
    print(x, "muy frío")
  elif(x >= 0 and x <= 24):
      print(x, "templado")
  else:
    print(x, "caluroso")
# Out:
# range(-30, 50)
# -30 muy frío
# -29 muy frío
# -28 muy frío
# -27 muy frío
# -26 muy frío
# -25 muy frío
# -24 muy frío
# -23 muy frío
# -22 muy frío
# -21 muy frío
# -20 muy frío
# -19 muy frío
# -18 muy frío
# -17 muy frío
# -16 muy frío
# -15 muy frío
# -14 muy frío
# -13 muy frío
# -12 muy frío
# -11 muy frío
# -10 muy frío
# -9 muy frío
# -8 muy frío
# -7 muy frío
# -6 muy frío
# -5 muy frío
# -4 muy frío
# -3 muy frío
# -2 muy frío
# -1 muy frío
# 0 templado
# 1 templado
# 2 templado
# 3 templado
# 4 templado
# 5 templado
# 6 templado
# 7 templado
# 8 templado
# 9 templado
# 10 templado
# 11 templado
# 12 templado
# 13 templado
# 14 templado
# 15 templado
# 16 templado
# 17 templado
# 18 templado
# 19 templado
# 20 templado
# 21 templado
# 22 templado
# 23 templado
# 24 templado
# 25 caluroso
# 26 caluroso
# 27 caluroso
# 28 caluroso
# 29 caluroso
# 30 caluroso
# 31 caluroso
# 32 caluroso
# 33 caluroso
# 34 caluroso
# 35 caluroso
# 36 caluroso
# 37 caluroso
# 38 caluroso
# 39 caluroso
# 40 caluroso
# 41 caluroso
# 42 caluroso
# 43 caluroso
# 44 caluroso
# 45 caluroso
# 46 caluroso
# 47 caluroso
# 48 caluroso
# 49 caluroso
# 50 caluroso

# %%
# lista desde 1 al 100

for x in range(1,101):

  # si es divisible por 5
  if(x % 5 == 0):

  # si también es divisible por 10
    if(x % 10 == 0):
      print(x, "Bip Bip")
    else:
      print(x, "Bip")
# Out:
# 5 Bip
# 10 Bip Bip
# 15 Bip
# 20 Bip Bip
# 25 Bip
# 30 Bip Bip
# 35 Bip
# 40 Bip Bip
# 45 Bip
# 50 Bip Bip
# 55 Bip
# 60 Bip Bip
# 65 Bip
# 70 Bip Bip
# 75 Bip
# 80 Bip Bip
# 85 Bip
# 90 Bip Bip
# 95 Bip
# 100 Bip Bip

# %%
# solicita 2 números, los sumas y muestra el puntaje de resultado

num1 = int(input("Ingresa primer puntaje: "))
num2 = int(input("Ingresa segundo puntaje: "))

# sumar los puntajes
suma = num1 + num2

# condiciones
# 1. si es menor a 50
if(suma < 50):
  print("Resultado: Nivel principiante")

# 2. si está entre 50 y 79
elif(suma >= 50 and suma < 80):
  print("Resultado: Nivel intermedio")

# 3. si es 80 o más
else:
  print("Resultado: Nivel pro")
# Out:
# Ingresa primer puntaje: 50
# Ingresa segundo puntaje: 10
# Resultado: Nivel intermedio

# %%
# perfil según edad y gusto

# datos usuario
edad = int(input("Ingresa tu edad: "))
le_gusta_musica = input("Te gusta la música (si/no): ")
le_gusta_bailar = input("Te gusta bailar (si/no): ")

# condiciones
# 1. mayor de edad, le gusta la música y le gusta bailar
if(edad >= 18 and le_gusta_musica == "si" and le_gusta_bailar == "si"):
  print("Eres una estrella de la fiesta")

# 2. le gusta la música pero no bailar
elif(le_gusta_musica == "si" and le_gusta_bailar == "no"):
  print("Te gusta la música, pero no tanto bailar")

# otro caso
else:
  print("Tienes tu propio estilo")
# Out:
# Ingresa tu edad: 18
# Te gusta la música (si/no): si
# Te gusta bailar (si/no): no
# Te gusta la música, pero no tanto bailar
